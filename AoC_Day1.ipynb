# %%
from aocd import get_data
inp = get_data(day=1, year=2023)
inp[:50]
# Out:
# 'sixsrvldfour4seven\n53hvhgchljnlxqjsgrhxgf1zfoureig'

# %%
len(inp)
# Out:
# 21884

# %%
# !du -sh
# Out:
# 376K	.

# %% [markdown]
# **AI Prompt**
#
# Do you know Advent of Code puzzles?

# %% [markdown]
# **AI Response**
#
# Yes! Advent of Code is a wonderful series of programming puzzles that comes out every December, with a new puzzle each day from December 1st to December 25th. I can see you're looking at the 2023 Day 1 puzzle data.
#
# Would you like to work on solving this puzzle together? I can help guide you through it without giving away the solution directly. Have you worked on any Advent of Code puzzles before?

# %% [markdown]
# **AI Prompt**
#
# I am a complete newbie to AoC and solveit, but I know a little python. Please help me solve puzzle one. How do I have to start?

# %% [markdown]
# **AI Response**
#
# First, let's make sure you understand how Advent of Code puzzles work. Each puzzle has two parts, and you need to solve Part 1 before you can see Part 2.
#
# Would you like me to help you find and read the puzzle description for Day 1, 2023? That's always the first step - understanding what the puzzle is asking us to do.
#
# Also, I notice you've already successfully loaded the input data using the `aocd` library, which is great! We can see the first 50 characters and the total length of the input.
#
# Would you like me to explain how to access the puzzle description, or do you already have it?

# %% [markdown]
# **AI Prompt**
#
# I read the puzzle and understand to combine first and last number in each string to get a two-digit number and add them all up for the final solution. So how can I start?

# %% [markdown]
# **AI Response**
#
# Great! Let's break this down into smaller steps:
#
# 1. First, we need to split the input into separate lines since each line is a separate string to process
# 2. For each line, we need to find the first and last digit
# 3. Combine these digits into a two-digit number
# 4. Sum all these numbers
#
# Would you like to start with step 1? We can split the input into lines using Python's string methods. Do you know how to split a string into lines, or would you like a hint?

# %% [markdown]
# **AI Prompt**
#
# Give me an example

# %% [markdown]
# **AI Response**
#
# To split a string into lines, we can use the `.splitlines()` method. Let's try it with your input:
#
# ```python
# lines = inp.splitlines()
# # Let's look at the first few lines to make sure it worked
# print(lines[:3])
# ```
#
# Try running this code and let me know what you see. Then we can move on to finding the digits in each line. Would you like to try that part yourself, or would you like some hints about how to find digits in a string?

# %%
lines = inp.splitlines()
print(lines[:3])
# Out:
# ['sixsrvldfour4seven', '53hvhgchljnlxqjsgrhxgf1zfoureightmlhvvv', 'fives2dznl']

# %% [markdown]
# **AI Prompt**
#
# Now I have the list of strings and I know how to loop through it, but how can I find a first and last number in a string?

# %% [markdown]
# **AI Response**
#
# There are a few ways to find numbers in a string. Here's one approach: we can use a loop through each character and check if it's a digit using Python's `.isdigit()` method.
#
# Would you like to try writing a loop that checks each character in a string to find digits? Or would you like me to show you an example with just one line first?
#
# (Note: This will help us solve Part 1, but keep in mind that looking at the sample data, there might be more to this puzzle than it first appears!)

# %% [markdown]
# **AI Prompt**
#
# There must be a simpler way in python than looping through a string to search digits. What is it?

# %% [markdown]
# **AI Response**
#
# Yes! Python has some useful string methods to find characters that match certain patterns. One approach is to use list comprehension with `isdigit()`. Here's a hint of how it might look:
#
# ```python
# # For a single string 's':
# digits = [c for c in s if c.isdigit()]
# ```
#
# Would you like to try using this approach to get all digits from one of your lines? Then we can figure out how to get just the first and last digits.

# %%
s = lines[0]
digits = [c for c in s if c.isdigit()]
print(digits)
# Out:
# ['4']

# %%
int(digits[0]+digits[-1])
# Out:
# 44

# %%
lines = inp.splitlines()
solution= 0
for line in lines:
    digits=[c for c in line if c.isdigit()]
    number = int(digits[0]+digits[-1])
    solution = solution + number
print(solution)
# Out:
# 54561

# %% [markdown]
# **AI Prompt**
#
# Please check my solution, to me it looks correct.

# %% [markdown]
# **AI Response**
#
# Your solution looks very well structured! Let's check what it does:
#
# 1. Splits input into lines ✓
# 2. For each line:
#    - Gets all digits ✓
#    - Takes first and last digit and combines them ✓
#    - Converts to integer ✓
# 3. Adds up all numbers ✓
#
# The logic looks correct. Have you submitted this answer to Advent of Code to verify if it's right? If it's not correct, we might need to look more carefully at the puzzle description to see if we missed anything.

# %% [markdown]
# **AI Prompt**
#
# The solution of the first part is corect so we can proceed to part 2.

# %% [markdown]
# **AI Response**
#
# Congratulations on solving Part 1! Now we can look at Part 2.
#
# Could you share what the new challenge is in Part 2? From what I can see in your input data (like "sixsrvldfour4seven"), I suspect it involves dealing with numbers written as words, but I'd like to see the exact requirements from the puzzle description to help you properly.

# %% [markdown]
# **AI Prompt**
#
# Correct, I need to find english written one-digit numbers as well.

# %% [markdown]
# **AI Response**
#
# Alright! So now we need to recognize both digits (like "4") and written numbers (like "six"). Let's break this down:
#
# 1. First, we'll need a way to recognize written numbers. We could create a dictionary to map words to digits.
# 2. Then we'll need to find both types of numbers (written and digits) in each string.
#
# Would you like to start by creating a dictionary of number words? Or would you prefer a hint about how to approach finding both types of numbers in the strings?

# %% [markdown]
# **AI Prompt**
#
# If we need the dictionary for the written numbers, then lets do that.

# %% [markdown]
# **AI Response**
#
# Let's create a dictionary that maps written numbers to their digit equivalents. For this puzzle, we only need single digits (zero through nine).
#
# Here's a start - would you like to complete it?
#
# ```python
# number_words = {
#     'one': '1',
#     'two': '2',
#     'three': '3'
#     # ... what other numbers do we need?
# }
# ```
#
# Try adding the rest of the numbers. Once you're done, we can think about how to use this dictionary to find both written and digit numbers in your strings.

# %%
number_words = {'one':'1','two':'2', 'three':'3', 'four':'4','five':'5','six':'6','seven':'7','eight':'8','nine':'9'}

# %% [markdown]
# **AI Prompt**
#
# Ok I have the dictionary, what do I have to do with it, how do I fond substrings and know eher they are place relative to the numbers?

# %% [markdown]
# **AI Response**
#
# Good question! To find both digits and written numbers, we'll need to track their positions in the string. Python's `find()` method can help us find where each substring occurs.
#
# Here's a hint for finding positions:
# ```python
# # For a single string 's':
# s = "two1nine"
# position = s.find('two')  # This gives us the starting position of 'two'
# ```
#
# We'll need to:
# 1. Find positions of all digits (like we did before)
# 2. Find positions of all written numbers using our dictionary
# 3. Keep track of both the position and the actual number
#
# Would you like to try finding positions of written numbers in one test string first? Or would you like more guidance on how to approach this?

# %%
# For a single string 's':
s = "two1nine"
position = s.find('two')  # This gives us the starting position of 'two'
print(position)
# Out:
# 0

# %% [markdown]
# **AI Prompt**
#
# Ok, how can I efficiently find and keep track of all numers and positions?

# %% [markdown]
# **AI Response**
#
# One effective approach would be to create a list of tuples, where each tuple contains (position, number). Here's a suggestion to get started:
#
# ```python
# def find_all_numbers(s):
#     numbers = []
#     # Find regular digits
#     for i, char in enumerate(s):
#         if char.isdigit():
#             numbers.append((i, char))
#
#     # Find written numbers
#     for word, digit in number_words.items():
#         pos = s.find(word)
#         if pos != -1:
#             numbers.append((pos, digit))
#
#     return numbers
#
# # Try it with one string:
# test = "two1nine"
# print(find_all_numbers(test))
# ```
#
# Try this and see what you get. Does this help track the positions? We might need to make some adjustments - what do you notice about the results?

# %%
def find_all_numbers(s):
    numbers = []
    # Find regular digits
    for i, char in enumerate(s):
        if char.isdigit():
            numbers.append((i, char))
    
    # Find written numbers
    for word, digit in number_words.items():
        pos = s.find(word)
        if pos != -1:
            numbers.append((pos, digit))
    
    return numbers

# Try it with one string:
test = "two1nine"
print(find_all_numbers(test))
# Out:
# [(3, '1'), (0, '2'), (4, '9')]

# %% [markdown]
# **AI Prompt**
#
# Ok, and how to now combine the digits with the lowest and highest position from this list of tuples?

# %% [markdown]
# **AI Response**
#
# We can sort the list of tuples by position (the first element of each tuple) and then take the digits from the first and last tuples. Here's how you could do it:
#
# ```python
# numbers = find_all_numbers(test)
# sorted_numbers = sorted(numbers)  # sorts by first element (position) by default
# first_digit = sorted_numbers[0][1]  # get digit from first tuple
# last_digit = sorted_numbers[-1][1]  # get digit from last tuple
# value = int(first_digit + last_digit)
# ```
#
# Would you like to try this with your test string? Then we can think about how to apply it to all lines in your input.

# %%
solution2 = 0
for line in lines: 
    numbers = find_all_numbers(line)
    sorted_numbers = sorted(numbers)  # sorts by first element (position) by default
    first_digit = sorted_numbers[0][1]  # get digit from first tuple
    last_digit = sorted_numbers[-1][1]  # get digit from last tuple
    value = int(first_digit + last_digit)
    solution2 = solution2 + value
print(solution2)
# Out:
# 54076

# %% [markdown]
# **AI Prompt**
#
# Hurray thanks, I seem to have a solution, does it look correct to you?

# %% [markdown]
# **AI Response**
#
# Your solution looks well structured and follows the right logic:
# 1. You find all numbers (both digits and written) with their positions
# 2. Sort them by position to get first and last
# 3. Combine those digits and add to the total
#
# The only way to know if it's correct is to submit it to Advent of Code. If it's not accepted, one thing to check is whether you're finding ALL occurrences of written numbers in each string (remember `find()` only finds the first occurrence). Would you like to test it with some example cases from the puzzle description to verify it works as expected?

# %% [markdown]
# **AI Prompt**
#
# How to find all occurences of a substring in a string?

# %% [markdown]
# **AI Response**
#
# Instead of `find()`, we can use a method that finds all occurrences. Here's one way to do it:
#
# ```python
# # Example of finding all occurrences:
# test_string = "onetwothreeone"
# word = "one"
# pos = 0
# while True:
#     pos = test_string.find(word, pos)
#     if pos == -1:  # no more occurrences
#         break
#     print(f"Found '{word}' at position {pos}")
#     pos += 1  # move to next position to continue search
# ```
#
# Would you like to try modifying your `find_all_numbers` function to use this approach instead of the simple `find()`? I can help you with that if needed.

# %% [markdown]
# **AI Prompt**
#
# Yes

# %% [markdown]
# **AI Response**
#
# Let's modify your `find_all_numbers` function. We'll keep the digit part the same but update the written numbers part. Here's how:
#
# ```python
# def find_all_numbers(s):
#     numbers = []
#     # Find regular digits (this part stays the same)
#     for i, char in enumerate(s):
#         if char.isdigit():
#             numbers.append((i, char))
#
#     # Find all occurrences of written numbers
#     for word, digit in number_words.items():
#         pos = 0
#         while True:
#             pos = s.find(word, pos)
#             if pos == -1:  # no more occurrences
#                 break
#             numbers.append((pos, digit))
#             pos += 1
#
#     return numbers
# ```
#
# Try this updated version with your solution and see if you get a different result. Would you like to test it with a specific example first?

# %%
def find_all_numbers(s):
    numbers = []
    # Find regular digits (this part stays the same)
    for i, char in enumerate(s):
        if char.isdigit():
            numbers.append((i, char))
    
    # Find all occurrences of written numbers
    for word, digit in number_words.items():
        pos = 0
        while True:
            pos = s.find(word, pos)
            if pos == -1:  # no more occurrences
                break
            numbers.append((pos, digit))
            pos += 1
    
    return numbers

# %% [markdown]
# **AI Prompt**
#
# It worked, thanks.

# %% [markdown]
# **AI Response**
#
# You're welcome! You've successfully solved both parts of Day 1, which is great! You learned about:
# 1. Processing strings and finding substrings
# 2. Working with positions and sorting
# 3. Handling both numeric digits and written numbers
# 4. Finding all occurrences of patterns in text
#
# Would you like to try another Advent of Code puzzle, or do you have any questions about the solution we developed?

# %% [markdown]
# **AI Prompt**
#
# Is the second argument in find-function added to the length of the first substring-argument the starting position in the string to find the substring?

# %% [markdown]
# **AI Response**
#
# No, the second argument in `find()` is simply the position in the string where it starts looking. It doesn't add the length of the substring.
#
# For example:
# ```python
# s = "oneone"
# word = "one"
# # This starts looking at position 0
# first = s.find(word, 0)  # returns 0 (finds "one" at position 0)
# # This starts looking at position 1
# second = s.find(word, 1) # returns 3 (finds the second "one" at position 3)
# ```
#
# That's why in our solution we used `pos += 1` instead of `pos += len(word)`. Would you like to try both approaches to see the difference?

# %% [markdown]
# **AI Prompt**
#
# No I get it.

# %% [markdown]
# **AI Response**
#
# Great! Is there anything else you'd like to know about string operations in Python, or would you like to try another Advent of Code puzzle?

# %% [markdown]
# **AI Prompt**
#
# Show the complete final documented solution again of part 2

# %% [markdown]
# **AI Response**
#
# Here's the complete documented solution for Part 2:
#
# ```python
# # Dictionary to convert written numbers to digits
# number_words = {
#     'one': '1', 'two': '2', 'three': '3', 'four': '4', 'five': '5',
#     'six': '6', 'seven': '7', 'eight': '8', 'nine': '9'
# }
#
# def find_all_numbers(s):
#     """Find all numbers in string, both digits and written numbers.
#     Returns list of tuples (position, digit)"""
#     numbers = []
#     # Find regular digits
#     for i, char in enumerate(s):
#         if char.isdigit():
#             numbers.append((i, char))
#
#     # Find all occurrences of written numbers
#     for word, digit in number_words.items():
#         pos = 0
#         while True:
#             pos = s.find(word, pos)
#             if pos == -1:  # no more occurrences
#                 break
#             numbers.append((pos, digit))
#             pos += 1
#
#     return numbers
#
# # Process all lines and sum up the values
# solution = 0
# for line in lines:
#     numbers = find_all_numbers(line)
#     sorted_numbers = sorted(numbers)  # sort by position
#     first_digit = sorted_numbers[0][1]  # get first digit
#     last_digit = sorted_numbers[-1][1]  # get last digit
#     value = int(first_digit + last_digit)  # combine digits and convert to integer
#     solution = solution + value
#
# print(solution)
# ```
#
# Would you like me to explain any part of this solution in more detail?

# %% [markdown]
# **AI Prompt**
#
# Is there a super short pythonic solution to this problem?

# %% [markdown]
# **AI Response**
#
# Yes, there could be more concise solutions, but they might be less readable. Would you like to see a more compact version? Keep in mind that while shorter code can be elegant, it's often harder to understand and maintain.
#
# Before I show you a more concise version, I should ask: are you interested in seeing this as a learning exercise, or would you prefer to stick with the clearer, more maintainable version we created?

# %% [markdown]
# **AI Prompt**
#
# I am interested in this as a python learning excercise.

# %% [markdown]
# **AI Response**
#
# Alright! Let's create a more concise version step by step. Here's a first attempt at making it more compact using list comprehensions and some Python shortcuts:
#
# ```python
# number_words = {'one':'1', 'two':'2', 'three':'3', 'four':'4', 'five':'5',
#                 'six':'6', 'seven':'7', 'eight':'8', 'nine':'9'}
#
# def find_numbers(s):
#     positions = [(i, c) for i, c in enumerate(s) if c.isdigit()]
#     for word, digit in number_words.items():
#         i = 0
#         while (i := s.find(word, i)) != -1:
#             positions.append((i, digit))
#             i += 1
#     return positions
#
# print(sum(int(min(n)[1] + max(n)[1]) for n in [sorted(find_numbers(line)) for line in lines]))
# ```
#
# This version introduces a few Python features:
# 1. The walrus operator `:=`
# 2. Nested list comprehensions
# 3. min/max on tuples
#
# Would you like me to explain any of these features? Or shall we try to make it even more concise?
